# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('../food5k-image-dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../food5k-image-dataset\evaluation\food\0.jpg
# ../food5k-image-dataset\evaluation\food\1.jpg
# ../food5k-image-dataset\evaluation\food\10.jpg
# ../food5k-image-dataset\evaluation\food\100.jpg
# ../food5k-image-dataset\evaluation\food\101.jpg
# ../food5k-image-dataset\evaluation\food\102.jpg
# ../food5k-image-dataset\evaluation\food\103.jpg
# ../food5k-image-dataset\evaluation\food\104.jpg
# ../food5k-image-dataset\evaluation\food\105.jpg
# ../food5k-image-dataset\evaluation\food\106.jpg
# ../food5k-image-dataset\evaluation\food\107.jpg
# ../food5k-image-dataset\evaluation\food\108.jpg
# ../food5k-image-dataset\evaluation\food\109.jpg
# ../food5k-image-dataset\evaluation\food\11.jpg
# ../food5k-image-dataset\evaluation\food\110.jpg
# ../food5k-image-dataset\evaluation\food\111.jpg
# ../food5k-image-dataset\evaluation\food\112.jpg
# ../food5k-image-dataset\evaluation\food\113.jpg
# ../food5k-image-dataset\evaluation\food\114.jpg
# ../food5k-image-dataset\evaluation\food\115.jpg
# ...

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
non_food = plt.imread('../food5k-image-dataset/validation/non_food/433.jpg')
plt.imshow(non_food)
plt.title('Non food category image')
# Out:
# Text(0.5, 1.0, 'Non food category image')

# %%
food = plt.imread('../food5k-image-dataset/validation/food/270.jpg')
plt.imshow(food)
plt.title('Food category image')
# Out:
# Text(0.5, 1.0, 'Food category image')

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(directory='../food5k-image-dataset/training',
                                                   target_size=(128,128),
                                                   classes=['food','non_food'],
                                                   class_mode='binary')
# Out:
# Found 3000 images belonging to 2 classes.
# float32

# %%
valid_datagen = ImageDataGenerator(
                    rescale = 1./255)

valid_generator = valid_datagen.flow_from_directory(directory='../food5k-image-dataset/validation',
                                                   target_size=(128,128),
                                                   classes=['food','non_food'],
                                                   class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(
                    rescale = 1./255)

test_generator = test_datagen.flow_from_directory(directory='../food5k-image-dataset/evaluation',
                                                   target_size=(128,128),
                                                   classes=['food','non_food'],
                                                   class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,kernel_initializer='he_normal',kernel_size=(3,3),input_shape=(128,128,3),activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2,2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(128,kernel_initializer='he_normal',kernel_size=(3,3),activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2,2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(256,kernel_initializer='he_normal',kernel_size=(3,3),activation='relu'))
model.add(tf.keras.layers.MaxPool2D(2,2))
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dense(1024,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 126, 126, 64)      1792
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 63, 63, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 30, 30, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 14, 14, 256)       0
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_3 (Dense)             (None, 512)               25690624
#
#  dense_4 (Dense)             (None, 1024)              525312
#
#  dense_5 (Dense)             (None, 1)                 1025
#
# ...

# %%
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
Y = model.fit(train_generator, epochs=5,validation_data=valid_generator)
# Out:
# Epoch 1/5
# 94/94 [==============================] - 182s 2s/step - loss: 2.5229 - accuracy: 0.6777 - val_loss: 0.4851 - val_accuracy: 0.8030
# Epoch 2/5
# 94/94 [==============================] - 173s 2s/step - loss: 0.4742 - accuracy: 0.7903 - val_loss: 0.3892 - val_accuracy: 0.8360
# Epoch 3/5
# 94/94 [==============================] - 121s 1s/step - loss: 0.4012 - accuracy: 0.8200 - val_loss: 0.3568 - val_accuracy: 0.8540
# Epoch 4/5
# 94/94 [==============================] - 117s 1s/step - loss: 0.3762 - accuracy: 0.8347 - val_loss: 0.3261 - val_accuracy: 0.8700
# Epoch 5/5
# 94/94 [==============================] - 122s 1s/step - loss: 0.3251 - accuracy: 0.8640 - val_loss: 0.3488 - val_accuracy: 0.8650

# %%
model.evaluate(test_generator,steps=len(test_generator))
# Out:
# 32/32 [==============================] - 15s 468ms/step - loss: 0.4436 - accuracy: 0.8140
# [0.4436429440975189, 0.8140000104904175]

# %%
model.save("1.h5")
